# %% [markdown]
# <a href="https://colab.research.google.com/github/tlmartiner/Aprendizaje_No_Supervisado/blob/main/Clase_7_Reducci%C3%B3n_dimensionalidad_clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # conexión con drive
drive.mount('/content/drive')
import pandas as pd # Manejo de Data Frame
import numpy as np # Manejo matricial
import warnings # Omitir warnings
warnings.filterwarnings("ignore") # Ignorar warning (me estresan los warnings >:|)
# librerías para Gráficos
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# Librerías para clustering
import statsmodels.api as sm
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.cluster import (KMeans, AgglomerativeClustering, DBSCAN)
from sklearn.decomposition import PCA # Análisis de componentes principales
from scipy.cluster.hierarchy import dendrogram,  linkage # Dendograma
# Score de silueta
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score, pairwise_distances_argmin_min
from sklearn.preprocessing import StandardScaler # estandarizar variables.
# Out:
# Mounted at /content/drive

# %%
datos = pd.read_csv("/content/drive/MyDrive/Aprendizaje no supervisado/2024-2/Bases de datos/CC GENERAL.csv")
datos = datos.drop( ["CUST_ID", "TENURE"], axis=1).dropna()
datos_marketing = pd.read_csv("/content/drive/MyDrive/Aprendizaje no supervisado/2024-2/Bases de datos/marketing_campaign.csv", sep="\t")
datos_marketing=datos_marketing.dropna()

# %% [markdown]
# # Coeficiente de correlación
#
# El **coeficiente de correlación de Pearson** mide la relación lineal entre dos variables continuas. Su fórmula es:
#
# $$
# r = \frac{\sum (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum (x_i - \bar{x})^2 \sum (y_i - \bar{y})^2}}
# $$
#
# Donde:
# - $r$ es el coeficiente de correlación de Pearson.
# - $x_i$ e $y_i$ son los valores de las variables \(X\) e \(Y\) para cada observación.
# - $\bar{x}$ y $\bar{y}$ son las medias de las variables \(X\) e \(Y\), respectivamente.
#
# Este coeficiente varía entre -1 y 1:
# - \(r = 1\) indica una correlación positiva perfecta.
# - \(r = -1\) indica una correlación negativa perfecta.
# - \(r = 0\) indica que no hay correlación lineal entre las variables.

# %%
sns.scatterplot( x=datos["BALANCE"], y=datos["PURCHASES"])
# Out:
# <Axes: xlabel='BALANCE', ylabel='PURCHASES'>

# %% [markdown]
# Visualemente observamos una posible relación entre BALANCE y PURCHASES. Pero ¿qué tan alta es la relación?

# %%
np.corrcoef( datos["BALANCE"], datos["PURCHASES"])
# Out:
# array([[1.        , 0.17608309],
#        [0.17608309, 1.        ]])

# %% [markdown]
# Con el coeficiente de correlación podemos entender el grado de relación entre dos variables.

# %%
sns.scatterplot( x=datos["BALANCE"], y=datos["PRC_FULL_PAYMENT"])
# Out:
# <Axes: xlabel='BALANCE', ylabel='PRC_FULL_PAYMENT'>

# %% [markdown]
# ¿Cómo es la relación entre estas variables?

# %% [markdown]
# Con pandas podemos obtener lo que se llama la matriz de correlación entre variables.

# %%
datos.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.310140   0.176083
# BALANCE_FREQUENCY                 0.310140           1.000000   0.122635
# PURCHASES                         0.176083           0.122635   1.000000
# ONEOFF_PURCHASES                  0.159985           0.095254   0.916780
# INSTALLMENTS_PURCHASES            0.122109           0.114739   0.679259
# CASH_ADVANCE                      0.495586           0.089036  -0.053760
# PURCHASES_FREQUENCY              -0.088459           0.228158   0.393000
# ONEOFF_PURCHASES_FREQUENCY        0.063832           0.187467   0.497384
# PURCHASES_INSTALLMENTS_FREQUENCY -0.069582           0.184159   0.316025
# CASH_ADVANCE_FREQUENCY            0.445307           0.181132  -0.124863
# CASH_ADVANCE_TRX                  0.382388           0.133265  -0.070277
# PURCHASES_TRX                     0.147887           0.183095   0.688732
# CREDIT_LIMIT                      0.535518           0.087682   0.358425
# PAYMENTS                          0.322830           0.039169   0.606782
# MINIMUM_PAYMENTS                  0.398669           0.132519   0.093842
# PRC_FULL_PAYMENT                 -0.333594          -0.156961   0.176447
#
#                                   ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# BALANCE                                   0.159985                0.122109
# BALANCE_FREQUENCY                         0.095254                0.114739
# PURCHASES                                 0.916780                0.679259
# ONEOFF_PURCHASES                          1.000000                0.329650
# INSTALLMENTS_PURCHASES                    0.329650                1.000000
# CASH_ADVANCE                             -0.033244               -0.066099
# PURCHASES_FREQUENCY                       0.265460                0.441193
# ONEOFF_PURCHASES_FREQUENCY                0.524514                0.211829
# PURCHASES_INSTALLMENTS_FREQUENCY          0.128380                0.511130
# CASH_ADVANCE_FREQUENCY                   -0.086413               -0.136455
# CASH_ADVANCE_TRX                         -0.048705               -0.076716
# PURCHASES_TRX                             0.545313                0.626083
# CREDIT_LIMIT                              0.320613                0.258057
# PAYMENTS                                  0.570850                0.385391
# MINIMUM_PAYMENTS                          0.048741                0.132156
# PRC_FULL_PAYMENT                          0.129890                0.178440
#
#                                   CASH_ADVANCE  PURCHASES_FREQUENCY  \
# BALANCE                               0.495586            -0.088459
# BALANCE_FREQUENCY                     0.089036             0.228158
# PURCHASES                            -0.053760             0.393000
# ONEOFF_PURCHASES                     -0.033244             0.265460
# INSTALLMENTS_PURCHASES               -0.066099             0.441193
# CASH_ADVANCE                          1.000000            -0.218566
# PURCHASES_FREQUENCY                  -0.218566             1.000000
# ONEOFF_PURCHASES_FREQUENCY           -0.090111             0.502123
# PURCHASES_INSTALLMENTS_FREQUENCY     -0.178873             0.862338
# CASH_ADVANCE_FREQUENCY                0.629030            -0.316771
# CASH_ADVANCE_TRX                      0.656911            -0.208749
# PURCHASES_TRX                        -0.078449             0.567168
# CREDIT_LIMIT                          0.304161             0.121372
# PAYMENTS                              0.459342             0.100715
# MINIMUM_PAYMENTS                      0.140094             0.002979
# PRC_FULL_PAYMENT                     -0.158566             0.305393
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE                                             0.063832
# BALANCE_FREQUENCY                                   0.187467
# PURCHASES                                           0.497384
# ONEOFF_PURCHASES                                    0.524514
# INSTALLMENTS_PURCHASES                              0.211829
# CASH_ADVANCE                                       -0.090111
# PURCHASES_FREQUENCY                                 0.502123
# ONEOFF_PURCHASES_FREQUENCY                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.143911
# CASH_ADVANCE_FREQUENCY                             -0.118225
# CASH_ADVANCE_TRX                                   -0.073384
# PURCHASES_TRX                                       0.544364
# CREDIT_LIMIT                                        0.295432
# PAYMENTS                                            0.244346
# MINIMUM_PAYMENTS                                   -0.030357
# PRC_FULL_PAYMENT                                    0.154073
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE                                                  -0.069582
# BALANCE_FREQUENCY                                         0.184159
# PURCHASES                                                 0.316025
# ONEOFF_PURCHASES                                          0.128380
# INSTALLMENTS_PURCHASES                                    0.511130
# CASH_ADVANCE                                             -0.178873
# PURCHASES_FREQUENCY                                       0.862338
# ONEOFF_PURCHASES_FREQUENCY                                0.143911
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000
# CASH_ADVANCE_FREQUENCY                                   -0.268924
# CASH_ADVANCE_TRX                                         -0.172811
# PURCHASES_TRX                                             0.529192
# CREDIT_LIMIT                                              0.063421
# PAYMENTS                                                  0.083424
# MINIMUM_PAYMENTS                                          0.030036
# PRC_FULL_PAYMENT                                          0.249547
#
#                                   CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# BALANCE                                         0.445307          0.382388
# BALANCE_FREQUENCY                               0.181132          0.133265
# PURCHASES                                      -0.124863         -0.070277
# ONEOFF_PURCHASES                               -0.086413         -0.048705
# INSTALLMENTS_PURCHASES                         -0.136455         -0.076716
# CASH_ADVANCE                                    0.629030          0.656911
# PURCHASES_FREQUENCY                            -0.316771         -0.208749
# ONEOFF_PURCHASES_FREQUENCY                     -0.118225         -0.073384
# PURCHASES_INSTALLMENTS_FREQUENCY               -0.268924         -0.172811
# CASH_ADVANCE_FREQUENCY                          1.000000          0.799593
# CASH_ADVANCE_TRX                                0.799593          1.000000
# PURCHASES_TRX                                  -0.136913         -0.069879
# CREDIT_LIMIT                                    0.132841          0.150261
# PAYMENTS                                        0.182340          0.255921
# MINIMUM_PAYMENTS                                0.098844          0.109727
# PRC_FULL_PAYMENT                               -0.260001         -0.176574
#
#                                   PURCHASES_TRX  CREDIT_LIMIT  PAYMENTS  \
# BALANCE                                0.147887      0.535518  0.322830
# BALANCE_FREQUENCY                      0.183095      0.087682  0.039169
# PURCHASES                              0.688732      0.358425  0.606782
# ONEOFF_PURCHASES                       0.545313      0.320613  0.570850
# INSTALLMENTS_PURCHASES                 0.626083      0.258057  0.385391
# CASH_ADVANCE                          -0.078449      0.304161  0.459342
# PURCHASES_FREQUENCY                    0.567168      0.121372  0.100715
# ONEOFF_PURCHASES_FREQUENCY             0.544364      0.295432  0.244346
# PURCHASES_INSTALLMENTS_FREQUENCY       0.529192      0.063421  0.083424
# CASH_ADVANCE_FREQUENCY                -0.136913      0.132841  0.182340
# CASH_ADVANCE_TRX                      -0.069879      0.150261  0.255921
# PURCHASES_TRX                          1.000000      0.273715  0.371477
# CREDIT_LIMIT                           0.273715      1.000000  0.426951
# PAYMENTS                               0.371477      0.426951  1.000000
# MINIMUM_PAYMENTS                       0.096311      0.126671  0.126630
# PRC_FULL_PAYMENT                       0.156789      0.052578  0.104668
#
#                                   MINIMUM_PAYMENTS  PRC_FULL_PAYMENT
# BALANCE                                   0.398669         -0.333594
# BALANCE_FREQUENCY                         0.132519         -0.156961
# PURCHASES                                 0.093842          0.176447
# ONEOFF_PURCHASES                          0.048741          0.129890
# INSTALLMENTS_PURCHASES                    0.132156          0.178440
# CASH_ADVANCE                              0.140094         -0.158566
# PURCHASES_FREQUENCY                       0.002979          0.305393
# ONEOFF_PURCHASES_FREQUENCY               -0.030357          0.154073
# PURCHASES_INSTALLMENTS_FREQUENCY          0.030036          0.249547
# CASH_ADVANCE_FREQUENCY                    0.098844         -0.260001
# CASH_ADVANCE_TRX                          0.109727         -0.176574
# PURCHASES_TRX                             0.096311          0.156789
# CREDIT_LIMIT                              0.126671          0.052578
# PAYMENTS                                  0.126630          0.104668
# MINIMUM_PAYMENTS                          1.000000         -0.140404
# PRC_FULL_PAYMENT                         -0.140404          1.000000

# %%
sns.heatmap( datos.corr())
# Out:
# <Axes: >

# %%
datos.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT'],
#       dtype='object')

# %%
sns.scatterplot( x=datos["PURCHASES"], y=datos["ONEOFF_PURCHASES"])
# Out:
# <Axes: xlabel='PURCHASES', ylabel='ONEOFF_PURCHASES'>

# %% [markdown]
# El **coeficiente de correlación de Spearman** es una medida no paramétrica que evalúa la relación entre dos variables ordinales o continuas, basándose en los rangos de los datos en lugar de los valores originales. Su fórmula es:
#
# $$
# r_s = 1 - \frac{6 \sum d_i^2}{n(n^2 - 1)}
# $$
#
# Donde:
# - $r_s$ es el coeficiente de correlación de Spearman.
# - $d_i$ es la diferencia entre los rangos de los dos valores correspondientes para cada observación.
# - $n$ es el número de observaciones.
#
# Este coeficiente varía entre -1 y 1:
# - $r_s = 1$ indica una correlación positiva perfecta.
# - $r_s = -1$ indica una correlación negativa perfecta.
# - $r_s = 0$ indica que no hay correlación entre las variables.

# %%
sns.heatmap( datos.corr("spearman"))
# Out:
# <Axes: >

# %%
sns.scatterplot( y=datos["PURCHASES"], x=datos["PURCHASES_FREQUENCY"])
# Out:
# <Axes: xlabel='PURCHASES_FREQUENCY', ylabel='PURCHASES'>

# %% [markdown]
# El **coeficiente de correlación de Kendall** $\tau$ mide la asociación entre dos variables ordinales o continuas, evaluando la concordancia y discordancia entre los pares de observaciones. Su fórmula es:
#
# $$
# \tau = \frac{(n_c - n_d)}{\frac{1}{2}n(n-1)}
# $$
#
# Donde:
# - $\tau$ es el coeficiente de correlación de Kendall.
# - $n_c$ es el número de pares concordantes (pares en los que los valores de ambas variables varían en la misma dirección).
# - $n_d$ es el número de pares discordantes (pares en los que los valores de las variables varían en direcciones opuestas).
# - $n$ es el número de observaciones.
#
# El valor de $\tau$ varía entre -1 y 1:
# - $\tau = 1$ indica una concordancia perfecta.
#
# ---
#
#
# - $\tau = -1$ indica una discordancia perfecta.
# - $\tau = 0$ indica que no hay asociación.

# %% [markdown]
# Este coeficiente de correlación permite obtener una mejor precisión para la relación entre variables ordinales.

# %%
datos_marketing["Education_level"] = datos_marketing["Education"].replace({'Graduation':2, 'PhD':4, 'Master':3, 'Basic':0, '2n Cycle':1} )

# %%
datos_marketing["Education_level"].value_counts()
# Out:
# Education_level
# 2    1116
# 4     481
# 3     365
# 1     200
# 0      54
# Name: count, dtype: int64

# %%
sns.scatterplot( x=datos_marketing["Education_level"], y=datos_marketing["Income"])
# Out:
# <Axes: xlabel='Education_level', ylabel='Income'>

# %%
variables_numericas=["Education_level",'MntWines', 'MntFruits',
       'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
       'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
       'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
       'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
       'AcceptedCmp2',"Income" ]
datos_marketing[variables_numericas].corr("kendall")
# Out:
#                      Education_level  MntWines  MntFruits  MntMeatProducts  \
# Education_level             1.000000  0.184680  -0.123017         0.056965
# MntWines                    0.184680  1.000000   0.355030         0.619960
# MntFruits                  -0.123017  0.355030   1.000000         0.532194
# MntMeatProducts             0.056965  0.619960   0.532194         1.000000
# MntFishProducts            -0.125582  0.359565   0.550344         0.540642
# MntSweetProducts           -0.126753  0.348726   0.542203         0.519801
# MntGoldProds               -0.100481  0.394415   0.413511         0.457879
# NumDealsPurchases           0.021000  0.048367  -0.082540        -0.010880
# NumWebPurchases             0.077692  0.570764   0.350774         0.518283
# NumCatalogPurchases         0.073690  0.645686   0.484286         0.685633
# NumStorePurchases           0.073058  0.621260   0.435861         0.596073
# NumWebVisitsMonth          -0.046838 -0.278469  -0.321874        -0.353870
# AcceptedCmp3                0.004020  0.028004   0.007065         0.006864
# AcceptedCmp4                0.056315  0.254377   0.023234         0.112925
# AcceptedCmp5                0.029443  0.300002   0.197142         0.271732
# AcceptedCmp1               -0.008692  0.247188   0.146705         0.233000
# AcceptedCmp2                0.017868  0.113528   0.002116         0.051589
# Income                      0.116179  0.632614   0.399106         0.618775
#
#                      MntFishProducts  MntSweetProducts  MntGoldProds  \
# Education_level            -0.125582         -0.126753     -0.100481
# MntWines                    0.359565          0.348726      0.394415
# MntFruits                   0.550344          0.542203      0.413511
# MntMeatProducts             0.540642          0.519801      0.457879
# MntFishProducts             1.000000          0.544090      0.409233
# MntSweetProducts            0.544090          1.000000      0.394494
# MntGoldProds                0.409233          0.394494      1.000000
# NumDealsPurchases          -0.090923         -0.079877      0.070664
# NumWebPurchases             0.345842          0.345676      0.423909
# NumCatalogPurchases         0.503529          0.482933      0.495854
# NumStorePurchases           0.430649          0.435481      0.392369
# NumWebVisitsMonth          -0.332724         -0.328704     -0.185400
# AcceptedCmp3               -0.020859         -0.013218      0.114825
# AcceptedCmp4                0.002520          0.005291      0.054475
# AcceptedCmp5                0.181180          0.212734      0.156956
# AcceptedCmp1                0.174974          0.184205      0.145124
# AcceptedCmp2               -0.000480         -0.000930      0.055875
# Income                      0.397178          0.391346      0.341635
#
#                      NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# Education_level               0.021000         0.077692             0.073690
# MntWines                      0.048367         0.570764             0.645686
# MntFruits                    -0.082540         0.350774             0.484286
# MntMeatProducts              -0.010880         0.518283             0.685633
# MntFishProducts              -0.090923         0.345842             0.503529
# MntSweetProducts             -0.079877         0.345676             0.482933
# MntGoldProds                  0.070664         0.423909             0.495854
# NumDealsPurchases             1.000000         0.230311            -0.027142
# NumWebPurchases               0.230311         1.000000             0.475236
# NumCatalogPurchases          -0.027142         0.475236             1.000000
# NumStorePurchases             0.083514         0.522876             0.547237
# NumWebVisitsMonth             0.320012        -0.057476            -0.417350
# AcceptedCmp3                 -0.012911         0.027982             0.090193
# AcceptedCmp4                 -0.000719         0.156646             0.164794
# AcceptedCmp5                 -0.230771         0.150883             0.283625
# AcceptedCmp1                 -0.160379         0.158864             0.262881
# AcceptedCmp2                 -0.047755         0.031761             0.091247
# Income                       -0.143148         0.402639             0.618513
#
#                      NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# Education_level               0.073058          -0.046838      0.004020
# MntWines                      0.621260          -0.278469      0.028004
# MntFruits                     0.435861          -0.321874      0.007065
# MntMeatProducts               0.596073          -0.353870      0.006864
# MntFishProducts               0.430649          -0.332724     -0.020859
# MntSweetProducts              0.435481          -0.328704     -0.013218
# MntGoldProds                  0.392369          -0.185400      0.114825
# NumDealsPurchases             0.083514           0.320012     -0.012911
# NumWebPurchases               0.522876          -0.057476      0.027982
# NumCatalogPurchases           0.547237          -0.417350      0.090193
# NumStorePurchases             1.000000          -0.346848     -0.072779
# NumWebVisitsMonth            -0.346848           1.000000      0.051819
# AcceptedCmp3                 -0.072779           0.051819      1.000000
# AcceptedCmp4                  0.171305          -0.023407     -0.079659
# AcceptedCmp5                  0.193268          -0.237550      0.080248
# AcceptedCmp1                  0.169449          -0.169511      0.095683
# AcceptedCmp2                  0.071573          -0.005072      0.071702
# Income                        0.544578          -0.485554     -0.012051
#
#                      AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# Education_level          0.056315      0.029443     -0.008692      0.017868
# MntWines                 0.254377      0.300002      0.247188      0.113528
# MntFruits                0.023234      0.197142      0.146705      0.002116
# MntMeatProducts          0.112925      0.271732      0.233000      0.051589
# MntFishProducts          0.002520      0.181180      0.174974     -0.000480
# MntSweetProducts         0.005291      0.212734      0.184205     -0.000930
# MntGoldProds             0.054475      0.156956      0.145124      0.055875
# NumDealsPurchases       -0.000719     -0.230771     -0.160379     -0.047755
# NumWebPurchases          0.156646      0.150883      0.158864      0.031761
# NumCatalogPurchases      0.164794      0.283625      0.262881      0.091247
# NumStorePurchases        0.171305      0.193268      0.169449      0.071573
# NumWebVisitsMonth       -0.023407     -0.237550     -0.169511     -0.005072
# AcceptedCmp3            -0.079659      0.080248      0.095683      0.071702
# AcceptedCmp4             1.000000      0.311314      0.242782      0.295050
# AcceptedCmp5             0.311314      1.000000      0.407878      0.222121
# AcceptedCmp1             0.242782      0.407878      1.000000      0.176637
# AcceptedCmp2             0.295050      0.222121      0.176637      1.000000
# Income                   0.182554      0.323453      0.269955      0.085779
#
#                        Income
# Education_level      0.116179
# MntWines             0.632614
# MntFruits            0.399106
# MntMeatProducts      0.618775
# MntFishProducts      0.397178
# MntSweetProducts     0.391346
# MntGoldProds         0.341635
# NumDealsPurchases   -0.143148
# NumWebPurchases      0.402639
# NumCatalogPurchases  0.618513
# NumStorePurchases    0.544578
# NumWebVisitsMonth   -0.485554
# AcceptedCmp3        -0.012051
# AcceptedCmp4         0.182554
# AcceptedCmp5         0.323453
# AcceptedCmp1         0.269955
# AcceptedCmp2         0.085779
# Income               1.000000

# %%
datos_marketing[variables_numericas].corr()
# Out:
#                      Education_level  MntWines  MntFruits  MntMeatProducts  \
# Education_level             1.000000  0.215037  -0.076176         0.048746
# MntWines                    0.215037  1.000000   0.387024         0.568860
# MntFruits                  -0.076176  0.387024   1.000000         0.547822
# MntMeatProducts             0.048746  0.568860   0.547822         1.000000
# MntFishProducts            -0.102180  0.397721   0.593431         0.573574
# MntSweetProducts           -0.094367  0.390326   0.571606         0.535136
# MntGoldProds               -0.093662  0.392731   0.396487         0.359446
# NumDealsPurchases           0.033001  0.008886  -0.134512        -0.121308
# NumWebPurchases             0.101154  0.553786   0.302039         0.307090
# NumCatalogPurchases         0.085696  0.634753   0.486263         0.734127
# NumStorePurchases           0.091191  0.640012   0.458491         0.486006
# NumWebVisitsMonth          -0.055965 -0.321978  -0.418729        -0.539484
# AcceptedCmp3                0.003521  0.061463   0.014424         0.018438
# AcceptedCmp4                0.062780  0.373143   0.006396         0.091618
# AcceptedCmp5                0.035387  0.473550   0.212871         0.376867
# AcceptedCmp1               -0.002379  0.351417   0.191816         0.313076
# AcceptedCmp2                0.024119  0.206185  -0.009980         0.043521
# Income                      0.149338  0.578650   0.430842         0.584633
#
#                      MntFishProducts  MntSweetProducts  MntGoldProds  \
# Education_level            -0.102180         -0.094367     -0.093662
# MntWines                    0.397721          0.390326      0.392731
# MntFruits                   0.593431          0.571606      0.396487
# MntMeatProducts             0.573574          0.535136      0.359446
# MntFishProducts             1.000000          0.583867      0.427142
# MntSweetProducts            0.583867          1.000000      0.357450
# MntGoldProds                0.427142          0.357450      1.000000
# NumDealsPurchases          -0.143241         -0.121432      0.051905
# NumWebPurchases             0.299688          0.333937      0.407066
# NumCatalogPurchases         0.532757          0.495136      0.442428
# NumStorePurchases           0.457745          0.455225      0.389180
# NumWebVisitsMonth          -0.446423         -0.422371     -0.247691
# AcceptedCmp3               -0.000219          0.001780      0.124958
# AcceptedCmp4                0.016105          0.029313      0.024015
# AcceptedCmp5                0.196277          0.259230      0.181397
# AcceptedCmp1                0.261608          0.245102      0.170132
# AcceptedCmp2                0.002345          0.010188      0.050734
# Income                      0.438871          0.440744      0.325916
#
#                      NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# Education_level               0.033001         0.101154             0.085696
# MntWines                      0.008886         0.553786             0.634753
# MntFruits                    -0.134512         0.302039             0.486263
# MntMeatProducts              -0.121308         0.307090             0.734127
# MntFishProducts              -0.143241         0.299688             0.532757
# MntSweetProducts             -0.121432         0.333937             0.495136
# MntGoldProds                  0.051905         0.407066             0.442428
# NumDealsPurchases             1.000000         0.241440            -0.012118
# NumWebPurchases               0.241440         1.000000             0.386868
# NumCatalogPurchases          -0.012118         0.386868             1.000000
# NumStorePurchases             0.066107         0.516240             0.517840
# NumWebVisitsMonth             0.346048        -0.051226            -0.522004
# AcceptedCmp3                 -0.023135         0.042958             0.104345
# AcceptedCmp4                  0.016077         0.162932             0.140182
# AcceptedCmp5                 -0.184253         0.141189             0.322471
# AcceptedCmp1                 -0.127374         0.159292             0.309026
# AcceptedCmp2                 -0.037981         0.034829             0.099915
# Income                       -0.083101         0.387878             0.589162
#
#                      NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# Education_level               0.091191          -0.055965      0.003521
# MntWines                      0.640012          -0.321978      0.061463
# MntFruits                     0.458491          -0.418729      0.014424
# MntMeatProducts               0.486006          -0.539484      0.018438
# MntFishProducts               0.457745          -0.446423     -0.000219
# MntSweetProducts              0.455225          -0.422371      0.001780
# MntGoldProds                  0.389180          -0.247691      0.124958
# NumDealsPurchases             0.066107           0.346048     -0.023135
# NumWebPurchases               0.516240          -0.051226      0.042958
# NumCatalogPurchases           0.517840          -0.522004      0.104345
# NumStorePurchases             1.000000          -0.432398     -0.068913
# NumWebVisitsMonth            -0.432398           1.000000      0.061307
# AcceptedCmp3                 -0.068913           0.061307      1.000000
# AcceptedCmp4                  0.178020          -0.028666     -0.079659
# AcceptedCmp5                  0.212954          -0.277883      0.080248
# AcceptedCmp1                  0.178743          -0.194773      0.095683
# AcceptedCmp2                  0.085271          -0.007362      0.071702
# Income                        0.529362          -0.553088     -0.016174
#
#                      AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# Education_level          0.062780      0.035387     -0.002379      0.024119
# MntWines                 0.373143      0.473550      0.351417      0.206185
# MntFruits                0.006396      0.212871      0.191816     -0.009980
# MntMeatProducts          0.091618      0.376867      0.313076      0.043521
# MntFishProducts          0.016105      0.196277      0.261608      0.002345
# MntSweetProducts         0.029313      0.259230      0.245102      0.010188
# MntGoldProds             0.024015      0.181397      0.170132      0.050734
# NumDealsPurchases        0.016077     -0.184253     -0.127374     -0.037981
# NumWebPurchases          0.162932      0.141189      0.159292      0.034829
# NumCatalogPurchases      0.140182      0.322471      0.309026      0.099915
# NumStorePurchases        0.178020      0.212954      0.178743      0.085271
# NumWebVisitsMonth       -0.028666     -0.277883     -0.194773     -0.007362
# AcceptedCmp3            -0.079659      0.080248      0.095683      0.071702
# AcceptedCmp4             1.000000      0.311314      0.242782      0.295050
# AcceptedCmp5             0.311314      1.000000      0.407878      0.222121
# AcceptedCmp1             0.242782      0.407878      1.000000      0.176637
# AcceptedCmp2             0.295050      0.222121      0.176637      1.000000
# Income                   0.184400      0.335943      0.276820      0.087545
#
#                        Income
# Education_level      0.149338
# MntWines             0.578650
# MntFruits            0.430842
# MntMeatProducts      0.584633
# MntFishProducts      0.438871
# MntSweetProducts     0.440744
# MntGoldProds         0.325916
# NumDealsPurchases   -0.083101
# NumWebPurchases      0.387878
# NumCatalogPurchases  0.589162
# NumStorePurchases    0.529362
# NumWebVisitsMonth   -0.553088
# AcceptedCmp3        -0.016174
# AcceptedCmp4         0.184400
# AcceptedCmp5         0.335943
# AcceptedCmp1         0.276820
# AcceptedCmp2         0.087545
# Income               1.000000

# %%
sns.heatmap( datos_marketing[variables_numericas].corr("kendall"))
# Out:
# <Axes: >

# %%
sns.heatmap( datos_marketing[variables_numericas].corr())
# Out:
# <Axes: >

# %% [markdown]
# # Correlación múltiple
#
# Este concepto se refiere a la correlación entre una variable dependiente y varias variables independientes. En lugar de comparar solo dos variables, estás observando cómo una variable está relacionada con un conjunto de otras variables. En regresión múltiple, esta correlación se denota por
#
# El **coeficiente de determinación** ($R^2$) es una medida que indica qué proporción de la varianza total en la variable dependiente está explicada por el modelo. La fórmula básica para $R^2$ es:
#
# $$
# R^2 = 1 - \frac{\text{SS}_{\text{res}}}{\text{SS}_{\text{tot}}}
# $$
#
# Donde:
# - $\text{SS}_{\text{res}}$ es la **suma de los cuadrados de los residuos** o errores (la diferencia entre los valores observados y los valores predichos por el modelo):
#   $$
#   \text{SS}_{\text{res}} = \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
#   $$
#   Donde $y_i$ son los valores observados y $\hat{y}_i$ son los valores predichos.
#
# - $\text{SS}_{\text{tot}}$ es la **suma total de cuadrados**, que mide la varianza total de los datos (la diferencia entre los valores observados y la media de los valores observados):
#   $$
#   \text{SS}_{\text{tot}} = \sum_{i=1}^{n} (y_i - \bar{y})^2
#   $$
#   Donde $\bar{y}$ es la media de los valores observados.
#
# ### Interpretación:
#
# - $R^2 = 1$: El modelo explica perfectamente la variación de los datos.
# - $R^2 = 0$: El modelo no explica ninguna variación de los datos, es decir, el modelo es tan bueno como la media de los datos.
# - $R^2$ negativo: Esto puede ocurrir si el modelo es peor que una línea horizontal en la media de los datos (ocurre en casos donde el ajuste no es adecuado).
#
# En resumen, el coeficiente $R^2$ mide qué tan bien un modelo de regresión se ajusta a los datos observados, con valores más cercanos a 1 indicando un mejor ajuste.
#
# Con el siguiente código se puede obtener un coeficiente $R^2$ para cada variable.

# %% [markdown]
# ¿Qué observan?

# %%
def correlacion_multiple(datos_numericos):
  S= datos_numericos.cov()
  S_inv= np.linalg.inv(S)
  Vector_Corre_Multiples = pd.Series((1 - 1/ (np.diag(S) * np.diag(S_inv))), index= datos_numericos.columns)
  return Vector_Corre_Multiples
correlacion_multiple(datos)
# Out:
# BALANCE                             0.623884
# BALANCE_FREQUENCY                   0.223834
# PURCHASES                           0.999979
# ONEOFF_PURCHASES                    0.999965
# INSTALLMENTS_PURCHASES              0.999883
# CASH_ADVANCE                        0.653212
# PURCHASES_FREQUENCY                 0.905363
# ONEOFF_PURCHASES_FREQUENCY          0.743770
# PURCHASES_INSTALLMENTS_FREQUENCY    0.892590
# CASH_ADVANCE_FREQUENCY              0.705736
# CASH_ADVANCE_TRX                    0.684240
# PURCHASES_TRX                       0.680111
# CREDIT_LIMIT                        0.456733
# PAYMENTS                            0.631346
# MINIMUM_PAYMENTS                    0.196251
# PRC_FULL_PAYMENT                    0.266602
# dtype: float64

# %% [markdown]
# ¿Qué quiere decir esto?

# %% [markdown]
# # Análisis de componentes principales
#
# La ecuación básica del **modelado de componentes principales (PCA)** es una transformación lineal que convierte las variables originales en un conjunto de nuevas variables, llamadas **componentes principales**, que son combinaciones lineales de las originales.
#
#
#
# Cada componente principal $Z_i$ se puede representar como una combinación lineal de las variables originales $X_1, X_2, ..., X_p$, según la siguiente ecuación:
#
# $$
# Z_1 = w_{11}X_1 + w_{12}X_2 + \dots + w_{1p}X_p
# $$
# $$
# Z_2 = w_{21}X_1 + w_{22}X_2 + \dots + w_{2p}X_p
# $$
# $$
# \vdots
# $$
# $$
# Z_m = w_{m1}X_1 + w_{m2}X_2 + \dots + w_{mp}X_p
# $$
#
# Donde:
# - $Z_1, Z_2, ..., Z_m$ son los componentes principales.
# - $w_{ij}$ son los coeficientes de los eigenvectores (los elementos de la matriz \(W\)).
# - $X_1, X_2, ..., X_p$ son las variables originales.
#
# ### Propiedades clave:
# - Los componentes principales son **no correlacionados** entre sí.
# - El primer componente principal (\(Z_1\)) captura la mayor cantidad de **varianza** de los datos, el segundo componente (\(Z_2\)) captura la segunda mayor cantidad de varianza, y así sucesivamente.

# %% [markdown]
# # Tarjetas de crédito

# %% [markdown]
# Con la función PCA podemos implementar

# %%
num_variables= datos.shape[1]
scale_feature=StandardScaler().fit_transform( datos )
pca= PCA(num_variables )
pca.fit( scale_feature)
# Out:
# PCA(n_components=16)

# %%
pd.DataFrame(pca.fit_transform( scale_feature)).corr()
# Out:
#               0             1             2             3             4   \
# 0   1.000000e+00 -7.382610e-17  2.702977e-16 -1.966601e-16 -2.012711e-17
# 1  -7.382610e-17  1.000000e+00  1.776470e-16 -6.175598e-16  1.887258e-16
# 2   2.702977e-16  1.776470e-16  1.000000e+00  6.235045e-16  2.661901e-16
# 3  -1.966601e-16 -6.175598e-16  6.235045e-16  1.000000e+00  8.357667e-17
# 4  -2.012711e-17  1.887258e-16  2.661901e-16  8.357667e-17  1.000000e+00
# 5   2.396123e-16  2.377091e-16  6.596865e-17 -5.463837e-17 -5.638718e-16
# 6  -4.274249e-17  1.738929e-16 -1.270123e-17  1.804381e-17  1.399225e-16
# 7   5.022989e-17 -3.629973e-18 -4.344045e-16 -1.824210e-16  4.711437e-17
# 8   3.120605e-18 -6.153172e-17  2.036240e-16  1.294120e-17 -2.784947e-16
# 9  -8.903228e-18 -1.493601e-16 -1.075436e-16 -2.220332e-16 -1.462045e-16
# 10  2.004950e-16  4.382492e-16 -5.027182e-16  6.427002e-16 -3.277914e-17
# 10  1.000000e+00 -5.855277e-16 -4.425937e-16  3.333312e-17 -1.375517e-16
# 11 -5.855277e-16  1.000000e+00  1.932069e-16  1.547857e-16 -1.660305e-16
# 12 -4.425937e-16  1.932069e-16  1.000000e+00  9.939460e-17  2.149382e-17
# 13  3.333312e-17  1.547857e-16  9.939460e-17  1.000000e+00  5.714124e-17
# 14 -1.375517e-16 -1.660305e-16  2.149382e-17  5.714124e-17  1.000000e+00
# 15 -1.613169e-16 -9.013038e-17 -1.623066e-16  9.882812e-19  6.334943e-17
#
#               15
# 0  -4.510519e-17
# 1   2.852737e-17
# 2  -7.562127e-17
# 3  -8.424010e-17
# 4   7.915865e-17
# 5   9.577039e-17
# 6  -9.099272e-17
# 7   3.451731e-17
# 8   9.953771e-17
# 9  -1.248698e-16
# 10 -1.613169e-16
# 11 -9.013038e-17
# 12 -1.623066e-16
# 13  9.882812e-19
# 14  6.334943e-17
# 15  1.000000e+00

# %% [markdown]
# Valor propio de la componente.

# %%
pca.explained_variance_
# Out:
# array([4.60773205e+00, 3.46398093e+00, 1.51430913e+00, 1.22257177e+00,
#        1.06482577e+00, 8.65366437e-01, 7.23486641e-01, 6.32799387e-01,
#        5.24659054e-01, 4.04449560e-01, 3.02419045e-01, 2.47494918e-01,
#        2.02501710e-01, 1.78799717e-01, 4.64450737e-02, 1.17321509e-05])

# %% [markdown]
# Proporción de varianza explicada por cada componente

# %%
pd.Series(pca.explained_variance_ratio_)
# Out:
# 0     2.879499e-01
# 1     2.164737e-01
# 2     9.463336e-02
# 3     7.640189e-02
# 4     6.654390e-02
# 5     5.407914e-02
# 6     4.521268e-02
# 7     3.954538e-02
# 8     3.278739e-02
# 9     2.527517e-02
# 10    1.889900e-02
# 11    1.546664e-02
# 12    1.265489e-02
# 13    1.117369e-02
# 14    2.902481e-03
# 15    7.331745e-07
# dtype: float64

# %% [markdown]
# Varianza explicada acumulada

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.28794991, 0.50442364, 0.59905701, 0.67545889, 0.7420028 ,
#        0.79608194, 0.84129462, 0.88084   , 0.91362739, 0.93890256,
#        0.95780157, 0.97326821, 0.9859231 , 0.99709679, 0.99999927,
#        1.        ])

# %%
sns.lineplot( x=range(1, num_variables+1), y=pca.explained_variance_ratio_.cumsum())
plt.xlabel("Componentes principales")
plt.ylabel("Varianza explicada acumulada")
# Out:
# Text(0, 0.5, 'Varianza explicada acumulada')

# %% [markdown]
# Generalmente se busca el número de componentes que expliquen entre un 80 a 90% de varianza explicada.
#
# Se observa que a partir de 6 componentes se llega a un 79.6% de variabilidad, y a partir de 7 se obtiene un 84% de variabilidad.

# %% [markdown]
# Extraer componentes

# %%
pca= PCA(6)
pca.fit( scale_feature)
# Out:
# PCA(n_components=6)

# %%
pd.DataFrame(pca.components_.T, index= datos.columns)
# Out:
#                                          0         1         2         3  \
# BALANCE                           0.091471  0.405980 -0.165108  0.286606
# BALANCE_FREQUENCY                 0.108653  0.127755 -0.453013  0.204101
# PURCHASES                         0.414047  0.049015  0.241090  0.100842
# ONEOFF_PURCHASES                  0.348531  0.069485  0.369073  0.165076
# INSTALLMENTS_PURCHASES            0.338312 -0.011882 -0.108201 -0.064993
# CASH_ADVANCE                     -0.029117  0.437180 -0.010858 -0.297788
# PURCHASES_FREQUENCY               0.325307 -0.187016 -0.366063 -0.199834
# ONEOFF_PURCHASES_FREQUENCY        0.295714 -0.015086  0.104488  0.086528
# PURCHASES_INSTALLMENTS_FREQUENCY  0.278284 -0.173923 -0.460345 -0.263068
# CASH_ADVANCE_FREQUENCY           -0.096986  0.429933 -0.099726 -0.244537
# CASH_ADVANCE_TRX                 -0.056052  0.416407 -0.098060 -0.359433
# PURCHASES_TRX                     0.392140 -0.012381 -0.082802  0.002118
# CREDIT_LIMIT                      0.209263  0.243725  0.102930  0.065947
# PAYMENTS                          0.264324  0.263912  0.286087 -0.149678
# MINIMUM_PAYMENTS                  0.058529  0.170454 -0.238045  0.415112
# PRC_FULL_PAYMENT                  0.132276 -0.195991  0.170277 -0.491109
#
#                                          4         5
# BALANCE                           0.100634 -0.249262
# BALANCE_FREQUENCY                -0.439300  0.063576
# PURCHASES                         0.014853  0.264667
# ONEOFF_PURCHASES                 -0.169417  0.190837
# INSTALLMENTS_PURCHASES            0.346484  0.275103
# CASH_ADVANCE                      0.068706 -0.080738
# PURCHASES_FREQUENCY              -0.104261 -0.152464
# ONEOFF_PURCHASES_FREQUENCY       -0.521025 -0.270605
# PURCHASES_INSTALLMENTS_FREQUENCY  0.156394  0.017492
# CASH_ADVANCE_FREQUENCY           -0.170625  0.177052
# CASH_ADVANCE_TRX                 -0.123483  0.175149
# PURCHASES_TRX                    -0.044273  0.134015
# CREDIT_LIMIT                      0.108972 -0.667154
# PAYMENTS                          0.169080  0.106964
# MINIMUM_PAYMENTS                  0.478357 -0.015526
# PRC_FULL_PAYMENT                  0.144179 -0.334094

# %% [markdown]
# La componente 1, que representa el 28% de variabilidad de los datos, esta compuesta por todas las variables que se relacionan con PURCHASE. Mientras que la componente 2, que representa el 21% de variabilidad esta compuesta por BALANCE y CASH.

# %%
z_componentes= pca.fit_transform( scale_feature)

sns.scatterplot( x=z_componentes[:,0], y=z_componentes[:,1])
# Out:
# <Axes: >

# %%
px.scatter_3d( x=z_componentes[:,0], y=z_componentes[:,1], z= z_componentes[:,2])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="48bdaf19-c1f9-447f-a7e5-5276562b06d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48bdaf19-c1f9-447f-a7e5-5276562b06d9")) {                    Plotly.newPlot(                        "48bdaf19-c1f9-447f-a7e5-5276562b06d9",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-1.731304055938929,-1.2449291531132776,0.905906668257534,-1.6512569927514258,0.19306359236721518,6.259127641973322,0.23202893624029483,-0.4997318606226788,-0.6324462028489225,0.49411849901667015,-0.7437122350929606,1.9217848140657363,1.498760612035211,-1.657580657883178,0.6809144398022654,-1.9360589309772405,-1.0128836569577038,0.43623767077882564,0.7132684870831006,-0.20766627203938834,5.394538480594574,0.3715107390721172,2.6673674216569117,-1.4654435284157918,0.1281401977048564,-
0.094546996125822,-1.1861424072405273,0.8483733708108824,-0.8631194109781706,-1.6022106708435206,-1.5457916532298333,-2.0219484124615303,0.13004610271958567,1.9499349663601924,0.8307569133040488,-1.506322761599161,-0.3737053697629797,-1.0399780442231144,-0.5402125974502228,0.8806284623421506,-1.1823424303442076,-1.6214179925815837,-0.15873335866996488,0.42052317959834845,-0.9311119772836273,-1.2916216127427629,-1.3318984600888453,-1.7152392292847838,0.48208172768387875,-0.1823518178069713,0.6762926959649898,-0.7780312605342454,-2.123789930757805,-1.225042210440455,0.8860513689564723,1.4979612132777094,0.1539489650111599,-0.2759509130808368,-1.6370541198330977,-1.6874733204195964,-0.21355083617715423,0.008160465424144574,-0.41638544696701846,0.4617829796293769,0.745193385446901,0.504414367518555,0.10132757031163643,1.2743948648 ...

# %%
sns.scatterplot( x=z_componentes[:,0], y=z_componentes[:,1], hue=labes_k)
plt.xlabel("Componente 1 28%" )
plt.ylabel("Componente 2 21%" )
# Out:
# Text(0, 0.5, 'Componente 2 21%')

# %% [markdown]
# Parece ser que el clúster 2, tiene menor valor en la componente 1 y 2. Siendo la compoente uno que representa las compras, mientras la componente dos representa principalmente por BALANCE y CASH.
# Es decir que el clúster 2 representa valores bajos en la componente de compra y la componente de BALANCE y CASH.
#
# Sin embargo, lo mejor es interpretar los resultados con los datos originales.

# %% [markdown]
# Utilizando análisis de componentes principales.

# %%
silueta_score=[] # puntaje de silueta
wcss =[] #
n_clusters= range( 2,10)
for k in n_clusters:
  k_means=KMeans(k, random_state=123)
  k_means.fit(z_componentes)
  wcss.append(k_means.inertia_ )
  silueta = silhouette_score(z_componentes, k_means.labels_)
  silueta_score.append(silueta)
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(n_clusters,wcss)
axs[0].set_title("Método del codo")
axs[0].set_xlabel("Número de clúster" )
axs[0].set_ylabel("wcss" )
axs[1].plot( n_clusters,silueta_score)
axs[1].set_title("Puntaje de silueta")
axs[1].set_xlabel("Número de clúster" )
axs[1].set_ylabel("silhouette score" )
plt.show()

# %%
k_means=KMeans(3, random_state=123)
k_means.fit(z_componentes)
labes_k = pd.Series(k_means.labels_).astype(str)
px.scatter_3d( x=z_componentes[:,0], y=z_componentes[:,1], z= z_componentes[:,2], color=labes_k )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d796c681-dab6-42c6-a0b4-7d515887db12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d796c681-dab6-42c6-a0b4-7d515887db12")) {                    Plotly.newPlot(                        "d796c681-dab6-42c6-a0b4-7d515887db12",                        [{"hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":[-1.731304055938929,0.905906668257534,-1.6512569927514258,0.19306359236721518,0.23202893624029483,-0.4997318606226788,-0.6324462028489225,0.49411849901667015,-0.7437122350929606,1.498760612035211,-1.657580657883178,-1.9360589309772405,-1.0128836569577038,0.43623767077882564,0.7132684870831006,-0.20766627203938834,0.3715107390721172,0.1281401977048564,-1.5152227293539982,-0.08193442093125373,-0.8177993136866797,1.3479211447414206,0.3278949697076451,-1.